# %%
# %matplotlib inline
import numpy as np
import seaborn as sns
from neurosynth.base.dataset import Dataset
dataset = Dataset.load("data/neurosynth_60_0.6.pkl")
from coactivation import coactivation_contrast
from plotting import make_thresholded_slices

# %%
contrast_mas = coactivation_contrast(dataset, 'masks/newDMN_4regions.nii.gz', q = 0.01)

# %%
#fig_z = make_thresholded_slices(contrast_mas, sns.color_palette('Set1', 4), 
#                       cut_coords=[-16], annotate=True)

fig_y1 = make_thresholded_slices(contrast_mas, sns.color_palette('Set1', 4), 
                       cut_coords=[-28], display_mode='y', annotate=False)
fig_y2 = make_thresholded_slices(contrast_mas, sns.color_palette('Set1', 4), 
                       cut_coords=[0], display_mode='y', annotate=False)
fig_y3 = make_thresholded_slices(contrast_mas, sns.color_palette('Set1', 4), 
                       cut_coords=[12], display_mode='y', annotate=False)

#fig_z.savefig('coactivation/DMN_coact_z.svg')
#fig_y.savefig('coactivation/DMN_hipp_y.svg')

# %%
colors = ["amber","dark blue grey"]
colors = sns.xkcd_palette(colors)
contrast_mas = coactivation_contrast(dataset, 'images/MPFC/cluster_labels_k2.nii.gz', q = 0.01)

# %%
#fig_z = make_thresholded_slices(contrast_mas, colors, 
#        cut_coords=range(-20, 19, 5), annotate=True)

fig_y = make_thresholded_slices(contrast_mas, sns.color_palette(colors), 
        cut_coords=range(-10,0, 1), display_mode='y', annotate=False)

#fig_z.savefig('coactivation/MPFC_coact_z.svg')
#fig_y.savefig('coactivation/MPFC_coact_y.svg')

# %%
colors = ["jungle green","yellow","red"]
colors = sns.xkcd_palette(colors)
contrast_mas = coactivation_contrast(
    dataset, 'images/PCC/cluster_labels_k3.nii.gz', q = 0.01)

# %%
#fig_z = make_thresholded_slices(contrast_mas, colors, 
#                       cut_coords=np.arange(-20, 15, 5), annotate=True)
fig_y = make_thresholded_slices(contrast_mas, sns.color_palette(colors), 
                       cut_coords=[-24], display_mode='y', annotate=True)

#fig_z.savefig('coactivation/PCC_coact_z.svg')
#fig_y.savefig('coactivation/PCC_coact_y.svg')

# %%
colors = ["clay","dodger blue","pink"]

colors = sns.xkcd_palette(colors)
contrast_mas = coactivation_contrast(
    dataset, 'images/lTPJ/cluster_labels_k3.nii.gz', q = 0.01)
fig_z = make_thresholded_slices(contrast_mas, colors, 
                       cut_coords=np.arange(-20, 60, 6), annotate=True)
fig_y = make_thresholded_slices(contrast_mas, sns.color_palette(colors), 
                       cut_coords=range(-60, 50, 18), display_mode='y', annotate=True)

fig_z.savefig('coactivation/lTPJ_coact_z.svg')
fig_y.savefig('coactivation/lTPJ_coact_y.svg')

# %%
colors = ["lighter green","bluey purple"]
colors = sns.xkcd_palette(colors)
contrast_mas = coactivation_contrast(
    dataset, 'images/rTPJ/cluster_labels_k2.nii.gz', q = 0.01)
fig_z = make_thresholded_slices(contrast_mas, colors, 
                       cut_coords=np.arange(16, 45, 4), annotate=True)
fig_y = make_thresholded_slices(contrast_mas, sns.color_palette(colors), 
                       cut_coords=range(-60, 50, 18), display_mode='y', annotate=True)

fig_z.savefig('coactivation/rTPJ_coact_z.svg')
fig_y.savefig('coactivation/rTPJ_coact_y.svg')
