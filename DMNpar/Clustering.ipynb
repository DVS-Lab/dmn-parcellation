# %% [markdown]
# # Clustering analysis
#
# In this first notebook, we conduct a k-means clustering analysis on using an included MFC mask.
# Fortunately, Neurosynth includes a set of functions to make this rather easy. In this case I will use the simple neurosynth.analysis.cluster.magic function that takes care of most of the heavy lifting for you.
#
# By default, the magic() function performs a k-means co-activation based analysis using the same methods as our manuscript.
#
# First lets import some basic necessities:

# %%
# %matplotlib inline
import seaborn as sns
from nilearn import plotting as niplt
from matplotlib.colors import ListedColormap
import numpy as np

# %% [markdown]
# Next, I load a previously generated Neurosynth dataset. This dataset was generated using version 0.4 of Neurosynth and the features are 60 topics generated using latent dietrich allocation (LDA). Feel free to generate a dataset using the latest version of Neurosynth and plug it into this analysis.

# %%
from neurosynth.base.dataset import Dataset
dataset = Dataset.load("data/neurosynth_60_0.6.pkl")

# %% [markdown]
# Here, I use the magic function to perform the clustering analaysis. For each N I specify, an image is generated and placed in images/. Note that I specifiy that at least 80 studies must activate each voxel to be included in the analysis to ensure a robust classification.
#
# The following analysis will compute co-activation between each MFC voxel and the rest of the brain (reduced into 100 PCA components), and use the resulting distance matrix for classification. Note that this step may be computationally intensive. You may use the Clusterable class in neurosynth.analysis.cluster for a more custom analysis to avoid repeating the PCA for each classification if you desire.

# %%
#from neurosynth.analysis.cluster import magic
#magic(dataset, roi_mask='masks/newDMN.nii.gz', min_studies_per_voxel=80, output_dir='images/whole/DMN/', n_clusters=4)
#magic(dataset, roi_mask='masks/newMPFC.nii.gz', min_studies_per_voxel=80, output_dir='images/MPFC/', n_clusters=2)
#magic(dataset, roi_mask='masks/newPCC.nii.gz', min_studies_per_voxel=80, output_dir='images/PCC/', n_clusters=2)
#magic(dataset, roi_mask='masks/newLTPJ.nii.gz', min_studies_per_voxel=80, output_dir='images/lTPJ/', n_clusters=2)
#magic(dataset, roi_mask='masks/newRTPJ.nii.gz', min_studies_per_voxel=80, output_dir='images/rTPJ/', n_clusters=2)
#magic(dataset, roi_mask='masks/newMPFC.nii.gz', min_studies_per_voxel=80, output_dir='images/MPFC/', n_clusters=3)
#magic(dataset, roi_mask='masks/newPCC.nii.gz', min_studies_per_voxel=80, output_dir='images/PCC/', n_clusters=3)
#magic(dataset, roi_mask='masks/newLTPJ.nii.gz', min_studies_per_voxel=80, output_dir='images/lTPJ/', n_clusters=3)
#magic(dataset, roi_mask='masks/newRTPJ.nii.gz', min_studies_per_voxel=80, output_dir='images/rTPJ/', n_clusters=3)

# %% [markdown]
# Next, I use nilearn's useful plotting functions to display the results on saggital and coronal slices

# %%
# Generate color palette
colors = sns.color_palette('Set1',2)
niplt.plot_roi('images/DMN/DMN_4regions.nii.gz', cut_coords=[4], display_mode='x', 
             draw_cross=False, cmap = ListedColormap(colors), alpha=0.8)

# %%
colors = sns.color_palette('Set1',4)
niplt.plot_roi('images/DMN/DMN_4regions.nii.gz', display_mode='y', cut_coords=np.arange(-60, 62, 24),
             draw_cross=False, cmap = ListedColormap(colors), alpha=0.7)
# Out:
# /Users/shaoming/anaconda/lib/python2.7/site-packages/numpy/ma/core.py:4144: UserWarning: Warning: converting a masked element to nan.
#   warnings.warn("Warning: converting a masked element to nan.")

# %%
colors = colors = ["amber","dark blue grey"]
colors = sns.xkcd_palette(colors)
niplt.plot_roi('images/MPFC/MPFC2.nii.gz', cut_coords=[4], display_mode='x', 
             draw_cross=False, cmap = ListedColormap(colors), alpha=0.8)

# %%
# Generate color palette
colors = ["jungle green","yellow","red"]
colors = sns.xkcd_palette(colors)
niplt.plot_roi('images/PCC/PCCk3.nii.gz', cut_coords=[4], display_mode='x', 
             draw_cross=False, cmap = ListedColormap(colors), alpha=0.8)

# %%
#Generate color palette
colors = ["clay","dodger blue","pink"]
colors = sns.xkcd_palette(colors)
niplt.plot_roi('images/lTPJ/lTPJ3.nii.gz', cut_coords=[-44], display_mode='x', 
             draw_cross=False, cmap = ListedColormap(colors), alpha=0.8)

# %%
niplt.plot_roi('images/lTPJ/lTPJ3.nii.gz', display_mode='y', cut_coords=np.arange(-68, -60, 4),
             draw_cross=False, cmap = ListedColormap(colors), alpha=0.7)

# %%
# Generate color palette
colors = ["lighter green","bluey purple"]
colors = sns.xkcd_palette(colors)
niplt.plot_roi('images/rTPJ/rTPJ2.nii.gz', cut_coords=[44], display_mode='x', 
             draw_cross=False, cmap = ListedColormap(colors), alpha=0.8)

# %%
niplt.plot_roi('images/rTPJ/rTPJ2.nii.gz', display_mode='y', cut_coords=np.arange(-72, -50, 6),
             draw_cross=False, cmap = ListedColormap(colors), alpha=0.7)
